# %% [markdown]
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# E6156 $-$ Topics in SW Engineering: <br>Cloud Computing<br>
#     <i>Backend-as-a-Service</i>
# </span>
# </center></b>
# <br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.3">
# Lecture 2: VMs/Containers, IaaS, Container-as-a-Service, <br>REST APIs, Introduction to Security, API Gateway
# (Draft 0.9)
# </span>
# </center></i>

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
display(HTML("<style>.output_result { max-width:80% !important; }</style>"))
display(HTML("<style>.prompt { display:none !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>
# <style>.output_result { max-width:80% !important; }</style>
# <style>.prompt { display:none !important; }</style>

# %% [markdown]
# # Today's Lecture
#
# 1. Milestone 1,2,3 project structure $-$ reminder<br><br>
#
# 1. REST continued $\rightarrow$ HATEOS.<br><br>
#
# 1. Introduction to security.<br><br>
#
# 1. Middleware.<br><br>
#
# 1. First look at "database as a service."
#     - Relational Data Service
#     - DynamoDB<br><br>
#
# 1. API gateway.

# %% [markdown]
# <br>
#
# # Milestone 1, 2, 3 Project Structure
#
# <br>
#
# ## Milestone 3 Target
#
# <br>
#
# <hr>
#
# | <img src="../../images/milestone_1_2_3.png"> |
# | :---: |
# | __Milestone 1, 2 and 3__ |
#
# <hr>
#
# <br>
#
# - We are working to the first major checkpoint at milestone 3.<br><br>
#
#
# - This will be the first major set of project reviews.<br><br>
#
# - I will start conducting milestone 2 project reviews this weekend to check status and provide help and feedback.

# %% [markdown]
# <br>
#
# ## Milestone 2 Status
#
# <br>
#
# <hr>
#
# | <img src="../../images/milestone_2_status.png"> |
# | :---: |
# | __Milestone 2__ |
#
# <hr>
#
# <br>
#
#
# __Expected Current Status__<br><br>
#
# 1. Static content served from S3.<br><br>
#
# 1. Three simple, "Hello world." microservices with deployments:
#     1. Elastic Beanstalk.
#     2. Elastic Compute Service.
#     3. Elastic Container Service.<br><br>
#
# 1. Pagination for at least one microservice.<br><br>
#
# 1. Microservice and static content projects in separate CodeCommit or GitHub repos.<br><br>

# %% [markdown]
# <br>
#
# # REST Continued $\rightarrow$ HATEOS
#
# <br>
#
# ## Reminder
# <br>
#
# - Some good, introductory tutorials on REST APIs and HATEOAS.
#     - [Thoughts on RESTful API Design](https://restful-api-design.readthedocs.io/en/latest/)
#     - [REST API Tutorial](https://restfulapi.net/)
#     <br><br>
#
# - There are many, many more. There are about 7 billion people in the world and about 8 billion guides to REST API best practices.<br><br>
#
# - "Representational State Transfer (REST) is a software architectural style that defines a set of constraints to be used for creating Web services. Web services that conform to the REST architectural style, called RESTful Web services (RWS), provide interoperability between computer systems on the Internet. RESTful Web services allow the requesting systems to access and manipulate textual representations of Web resources by using a uniform and predefined set of stateless operations." (https://en.wikipedia.org/wiki/Representational_state_transfer)
# <br>
#
# - REST has six characteristics, which we will cover:
#     1. Uniform interface
#     2. Client–server
#     3. Stateless
#     4. Cacheable
#     5. Layered system
#     6. Code on demand (optional)
#
# <br>
# <hr style="height:3px">
#
# | <img src="../../images/rest_api.jpg" width="900px"> |
# | :---: |
# | [REST APIs](https://restful-api-design.readthedocs.io/en/latest/scope.html) |
#
# <hr style="height:3px">
# <br>

# %% [markdown]
# <br>
#
# ## API and Protocol
#
# <br><br>
#
# | <img src="../../images/http_rest_protocol.jpeg" > |
# | :---: |
# | __HTTP and REST__ |
#
# <br>
#
# - The CRUD verbs are:
#     - ```POST```
#     - ```GET```
#     - ```PUT``` (some designs use ```PATCH``` instead of ```PUT.```)
#     - ```DELETE```
#
# - The CRUD verbs occur on resources that a ```URL``` (```PATH```) identify.<br><br>
#
#
# - A URL has the format<br><br>
#
#
# ```URI = scheme:[//authority]path[?query][#fragment]```
#
# <br><br>
#
#
# - The components are:
#     1. Scheme: Information about the protocol, connector library, ...
#     2. Authority: Usually ```userid:password```.
#     3. Path: File system like folder path to the resource.
#     4. Query string.
#     5. Fragment: A location or subset of the resource, e.g. a section with heading.<br><br>
#
# - REST methods and response also have _headers._
# <br><br>
#
# - This means that there are several parameters for a REST method.
#     1. Path.
#     3. Method.
#     2. Path parameters.
#     3. Query parameters.
#     4. Body (usually just for ```PUT, POST, GET.)```
#     5. Headers.<br><br>
#
# - URL paths have a pattern in most applications<br><br>
#
# | Path | Mapping |
# | :---: | :--- |
# | /api	| The API entry point |
# | /api/:coll	| A top-level collection named “coll” |
# | /api/:coll/:id	| The resource “id” inside/related to collection “coll” |
# | /api/:coll/:id/:subcoll	| Sub-collection “subcoll” under resource “id” |
# | /api/:coll/:id/:subcoll/:subid	| The resource “subid” inside “subcoll” |
#
# <br><br>
#
# - Path examples:
#     - ```/api/GoT/seasons```
#     - ```/api/GoT/characters/CH_12```
#     - ```/api/GoT/characters/CH_12/scenes/locations```<br><br>

# %% [markdown]
# - Query string:<br>
#
# "On the internet, a query string is the part of a uniform resource locator (URL) which assigns values to specified parameters. The query string commonly includes fields added to a base URL by a Web browser or other client application, for example as part of an HTML form.
#
# A web server can handle a Hypertext Transfer Protocol request either by reading a file from its file system based on the URL path or by handling the request using logic that is specific to the type of resource. In cases where special logic is invoked, the query string will be available to that logic for use in its processing, along with the path component of the URL." (https://en.wikipedia.org/wiki/Query_string)<br><br>
#
# - Query string example:
#     - ```http://127.0.0.1/api/GoT/characters?characterName=Sansa Stark```
#     - maps to
#     - ```SELECT * FROM characters where characterName='Sansa Stark'```
# <br><br>
#
# - There is no standard way to specify _project._ A common convent is ```fields=f1,f2,...```

# %% [markdown]
# <br><br>
#
#
# <hr>
#
# | <img src="../../images/orders_weak.jpeg"> |
# | :---: |
# | __Classic Models Database__ |
#
# <hr>
#
# <br>
#
# - I decided to switch the example project I will build to extending [Classic Models DB](https://www.mysqltutorial.org/mysql-sample-database.aspx/)<br><br>
#
# - Students will find concepts more familiar than fantasy baseball.<br><br>

# %% [markdown]
# <br>
#
# __Example Path 1:__
#
#
# <br><br>
#
# http://127.0.0.1/api/customers?state=MA&fields=customerNumber,customerName,creditLimit&limit=5&offset=1
#
# <br><br>
#
# - If the method is GET, the operation is approximately equivalent to <br><br>
#
# ```select customerNumber, customerName, creditLimit from customers where state='MA' limit 3 offset 1```
#
#
# <br><br>
#
# - The response to a ```GET``` would be something like ...
#
# <br><br>
#
# ```
#
#  {
#    "data": [
#       {
#          "links": [
#             {
#                "rel": "orders",
#                "href": "/orders&customerNumber=129"
#             }
#          ],
#          "data": {
#             "customerNumber": 129,
#             "customerName": "Mini Wheels Co.",
#             "state": "CA",
#             "creditLimit": "64600.00"
#          }
#       },
#       {
#          "links": [
#             {
#                "rel": "orders",
#                "href": "/orders&orderNumber=161"
#             }
#          ],
#          "data": {
#             "customerNumber": 161,
#             "customerName": "Technics Stores Inc.",
#             "state": "CA",
#             "creditLimit": "84600.00"
#          }
#       },
#       {
#          "links": [
#             {
#                "rel": "orders",
#                "href": "/orders&orderNumber=205"
#             }
#          ],
#          "data": {
#             "customerNumber": 205,
#             "customerName": "Toys4GrownUps.com",
#             "state": "CA",
#             "creditLimit": "90700.00"
#          }
#       }
#    ],
#    "links": [
#       {
#          "rel": "next",
#          "href": "/customers?state=CA&fields=customerNumber,customerName,state,creditLimit&limit=3&offset=4"
#       },
#       {
#          "rel": "prev",
#          "href": "/customers?state=CA&fields=customerNumber,customerName,state,creditLimit&limit=3&offset=0"
#       },
#       {
#          "rel": "self",
#          "href": "http://127.0.0.1/api/customers?state=MA&fields=customerNumber,customerName,creditLimit&limit=5&offset=1"
#       }
#    ]
# }
#
# ```
#
# <br><br>
#
# - __What's with all the links, grandpa?__
#
# <br><br>

# %% [markdown]
# <br>
#
# ## HATEOAS
#
# <br>
#
# ### Concept
#
# <br>
#
# <hr>
#
# | <img src="../../images/rest_concepts.png"> |
# | :---: |
# | [Resource Concept](https://restful-api-design.readthedocs.io/en/latest/resources.html) |
#
# <hr>
#
# <br>

# %% [markdown]
# <br>
#
# - from [REST API Tutorial](https://restfulapi.net/hateoas/)<br><br>
#
# "HATEOAS (Hypermedia as the Engine of Application State) is a constraint of the REST application architecture that keeps the RESTful style architecture unique from most other network application architectures. The term “hypermedia” refers to any content that contains links to other forms of media such as images, movies, and text.
# <br>
#
# REST architectural style lets us use the hypermedia links in the response contents. It allows the client can dynamically navigate to the appropriate resources by traversing the hypermedia links.
# <br>
#
# Navigating hypermedia links is conceptually the same as a web user browsing through web pages by clicking the relevant hyperlinks to achieve a final goal."
# <br>
#
# <br>
#
# __What does this mean?__<br><br>
#
# 1. Explicit use of hyperlinks.
#     - The client does not have to know how to convert a ```customerNumber```
#     - Into a URL to access the resource.<br><br>
# 2. Explicit use of the ```Content-Type``` headers to indicate how to interpret body data.<br><br>
#
# <br>
#
# <hr>
#
# | <img src="../../images/hateoas_1.png"> |
# | :---: |
# | [HATEOAS Example](https://en.wikipedia.org/wiki/HATEOAS) |
#
# <hr>
#
# <br>
#
# <br>
#
# <hr>
#
# | <img src="../../images/hateoas_1.png"> |
# | :---: |
# | [HATEOAS Example](https://en.wikipedia.org/wiki/HATEOAS) |
#
# <hr>
#
# <br>

# %% [markdown]
# <br>
#
# - Let's unpack this a little bit.<br><br>
#
# - If the data has ```"customerNumber": "123"```, the links contains ```/customers/123``` to indicate that the URL to the related customer.<br><br>
#
# - In the example, the links section indicates that a python function<br><br>
# ```
# def deposit(accountNumber, amount)
# ```
# <br><br>
#
# - With a call like<br><br>
# ```
# def deposit(123, 200.0)
# ```
#
# <br><br>
#
# - Has the resource path ```/accounts/123/deposit```
#
# <br><br>
#
# - With the body <br><br>
# ```
# {
#     "amount": 200
# }
# ```
# <br><br>
#
# - And ```Content-Types, Accepts, ...``` headers indicating JSON and perhaps the data format.
#
# <br><br>
#
# - We can use the [Open API Specification (aka Swagger)](https://swagger.io/specification/)<br><br>
#
# <hr>
#
# | <img src="../../images/swagger_1.png"> |
# | :---: |
# | [OAS Petstore Example](Example) |
#
# <hr>
#
# <br>
#
# - Do some OAS demos here.
#     - [Open API editor]https://editor.swagger.io/
#     - [Swagger Hub]https://app.swaggerhub.com/home
#     - [Open API Map]http://openapi-map.apihandyman.io/?version=2.0<br><br>
#
# - You can define APIs "top down."
#     - Define Open API for service.
#     - Generate code template.
#     - Implement methods.<br><br>
#
# - Start with your implementation code and ["annotate"](https://swagger.io/blog/api-development/swagger-annotation-libraries/) the methods, e.g.<br><br>
#
# ```
# from flask import Flask
# from flask_restplus import Api, Resource, fields
#
# app = Flask(__name__)
# api = Api(app, version='1.0', title='TodoMVC API',
#     description='A simple TodoMVC API',
# )
#
# ns = api.namespace('todos', description='TODO operations')
#
# todo = api.model('Todo', {
#     'id': fields.Integer(readOnly=True, description='The task unique identifier'),
#     'task': fields.String(required=True, description='The task details')
# })
#
#
# class TodoDAO(object):
#     def __init__(self):
#         self.counter = 0
#         self.todos = []
#
#     def get(self, id):
#         for todo in self.todos:
#             if todo['id'] == id:
#                 return todo
#         api.abort(404, "Todo {} doesn't exist".format(id))
#
#     def create(self, data):
#         todo = data
#         todo['id'] = self.counter = self.counter + 1
#         self.todos.append(todo)
#         return todo
#
#     def update(self, id, data):
#         todo = self.get(id)
#         todo.update(data)
#         return todo
#
#     def delete(self, id):
#         todo = self.get(id)
#         self.todos.remove(todo)
#
#
# DAO = TodoDAO()
# DAO.create({'task': 'Build an API'})
# DAO.create({'task': '?????'})
# DAO.create({'task': 'profit!'})
#
#
# @ns.route('/')
# class TodoList(Resource):
#     '''Shows a list of all todos, and lets you POST to add new tasks'''
#     @ns.doc('list_todos')
#     @ns.marshal_list_with(todo)
#     def get(self):
#         '''List all tasks'''
#         return DAO.todos
#
#     @ns.doc('create_todo')
#     @ns.expect(todo)
#     @ns.marshal_with(todo, code=201)
#     def post(self):
#         '''Create a new task'''
#         return DAO.create(api.payload), 201
#
#
# @ns.route('/<int:id>')
# @ns.response(404, 'Todo not found')
# @ns.param('id', 'The task identifier')
# class Todo(Resource):
#     '''Show a single todo item and lets you delete them'''
#     @ns.doc('get_todo')
#     @ns.marshal_with(todo)
#     def get(self, id):
#         '''Fetch a given resource'''
#         return DAO.get(id)
#
#     @ns.doc('delete_todo')
#     @ns.response(204, 'Todo deleted')
#     def delete(self, id):
#         '''Delete a task given its identifier'''
#         DAO.delete(id)
#         return '', 204
#
#     @ns.expect(todo)
#     @ns.marshal_with(todo)
#     def put(self, id):
#         '''Update a task given its identifier'''
#         return DAO.update(id, api.payload)
#
#
# if __name__ == '__main__':
#     app.run(debug=True)
#
# ```

# %% [markdown]
# <br>
#
# ### Some Comments
#
# <br>
#
# - It is easy to go crazy with complying with HATEOAS, REST best practices, Open API, ... ...<br><br>
#
# - Discussion and arguments often sound like religious wars.<br><br>
#
#
# - I just want you to do some basic, simple HATEOAS concepts and REST practices. We will specify.<br><br>
#
# - I think defining one service's API in OAS is useful and would look good on resumes. You do not actually have to implement the service, generate the code, annotate code, ... ...<br><br>
#
# - All this GET and PUT stuff is fine, but how do I do something like ```transfer(sourceAcct, targetAcct, ammount)```?
# <br><br>
#
# - Does the client have to make several REST calls?
#     - ```GET /accounts/123```
#     - ```GET /accounts/456```
#     - Do some math on balances.
#     - ```PUT /accounts/123```
#     - ```PUT /accounts/123```<br><br>
#
# - That would be almost as annoying as Professor Ferguson.<br><br>
#
# - The way to think about this is:
#     - There are resources that you ```CRUD,``` e.g. "nouns" like ```Customer, Account, ...```
#     - There are resources that look like ```verbs`` but are the ```noun``` representing the action, e.g.
#         - "Create a transfer resource that represents the act of performing the transfer."
#         - The ```CREATE``` returns a URL to the created action.
#         - You can use ```GET``` on the URL to obtain the result.<br><br>
#
# ```
# POST /api/db/classicmodels/orders/cancel HTTP/1.1
# Host: 0.0.0.0:8025
# Content-Type: application/json
#
# {
#     "reason": "Delivery to late."
# }
# ```
#
# <br><br>
#
# - Response is something like ... ...<br><br>
#
# ```
# Request URL: http://0.0.0.0:8025//api/db/classicmodels/orders/cancel
# Request Method: POST
# Status Code: 201 CREATED
# Link: http://0.0.0.0:8025/api/db/classicmodels/orders/cancel/1101; rel="cancel result"
#
# ```

# %% [markdown]
# <br>
#
# # Some Basics of Security and Tokens
#
# <br>
#
# | <img src="../../images/jwt_0.png"> |
# | :---: |
# | [JWT Concept](https://auth0.com/docs/jwt) |
#
# | <img src="../../images/jwt_1.png"> |
# | :---: |
# | [JWT Concept](https://medium.com/@rose.espiritu1/jwt-tokens-ad8ed3a27494) |
#
# - In our simple example, the ```User``` microservice is the authentication sever. This is not the typical approach and violates the single responsibility principle.

# %% [markdown]
# - There are three parts to a JSON Web Token
#
# | <img src="../../images/jwt_2.png"> |
# | :---: |
# | [JWT Elements](https://nordicapis.com/why-cant-i-just-send-jwts-without-oauth/) |
#
#
# - The core is the __Payload.__
#
# | <img src="../../images/jwt_payload.png" width="800px"> |
# | :---: |
# | [JWT Elements](https://nordicapis.com/why-cant-i-just-send-jwts-without-oauth/) |

# %% [markdown]
# - "What is this 'claim magic' of which you speak?"
#
# | <img src="../../images/jwt_3.png" width="900px"> |
# | :---: |
# | [JWT Claims](https://auth0.com/docs/tokens/jwt-claims) |

# %% [markdown]
# - How does this work?
#     1. User authenticates to a ["security token service."](https://en.wikipedia.org/wiki/Security_token_service) using a shared secret, proof of ownership of a certificate, etc.
#     2. The STS issues a token containing claims, and signs the token. The STS signature is proof that the STS issues the claims and stands behind the claims.
#     3. A recipient of a request with a token can verify the token based on how the issues worked:
#         - By communicating with the issuer.
#         - Verifying the signature using public key infrastructure.
#
#
# | <img src="../../images/sts_1.png" width="900px"> |
# | :---: |
# | [STS](http://geocatalogo.sei.ba.gov.br/portal-doc/ERDAS%20APOLLO%20Geospatial%20Portal%20Administrator%20Guide/366862.htm) |
#
# - We are doing a "see spot run" version of this model.
#
#
# - This explanation has been a very, very simple overview of a space that is a semester course of its own.
#
#
# - You can use a shared secret and simple JSON objects, and you do not need to do formal claims and JWTs.

# %% [markdown]
# <br>
#
# # Middleware
#
# <br>
#
# ## Concept
#
# - "Middleware is computer software that provides services to software applications beyond those available from the operating system. It can be described as "software glue." (https://en.wikipedia.org/wiki/Middleware)
#
#
# - That is vague. Consider a simpler example. We want to add two functions to _all_ of our routes:
#     1. Log requests.
#     2. Check authentication and authorization.
#     3. Emit an event whenever a service changes a resources state, e.g. customer data changed.
#     3. Log responses.
#
#
# - Every route would look like the following:
#
# ```
# @application.route("/api/test_middleware/<parameter>", methods=["GET", "PUT", "DELETE", "POST"])
# def test_middleware(parameter):
#
#     security_middleware.authorize(request.url, request.method,
#                                   request.headers.get("Authorization", None))
#     logger.debug("/api/user/<email>" + json.dumps(request, default=str))
#
#     # Other middleware goes here ...
#
#
#     # Now do the application functions.
#
#
#     # And now do the functions for post processing the request.
#     logger.debug("/api/user/<email>" + json.dumps(request, default=str))
#     if request.method in ('POST', 'PUT', 'DELETE'):
#         notification_middleware.publish_change_event(request.url, request.json)
#
#     # More stuff goes here.
#
#     return "something"
# ```
#
# - This is inflexible and difficult to change.
#
#
# - Application severs introduce the concept of middleware.
#
# | <img src="../../images/node_express_mw.png" width="900px"> |
# | :---: |
# | [Node Express Middleware](http://www.acuriousanimal.com/2018/02/15/express-async-middleware.html) |

# %% [markdown]
# | <img src="../../images/tomcat_axis.gif" width="900px"> |
# | :---: |
# | [Axis Handler Chains](https://www.enterpriseintegrationpatterns.com/patterns/messaging/ComposedMessagingWS.html) |

# %% [markdown]
# <br>
#
# ## Flask Implementation
#
# - There are a few ways to do this in Flask. There are also some good [overviews.](https://pythonise.com/feed/flask/python-before-after-request)<br><br>
#
# - There are other ways for Flask, and ways for NodeJS, Django, Tomcat, ... ...<br><br>
#
#
# - This is an example of a simple application with some of the options.
#
# ```
# import json
# import logging
# from datetime import datetime
# from flask import Flask, Response, request
# from functools import wraps
# from flask import g, request, redirect, url_for
# from flask import Response
# from werkzeug.wrappers import Response as wResponse
# from functools import wraps
# from flask import g, request, redirect, url_for
#
#
# # This is the top-level application that receives and routes requests.
# application = Flask(__name__)
#
#
# def login_required(f):
#     @wraps(f)
#     def decorated_function(*args, **kwargs):
#         print("\nDecorator was called!!!!. Request = ", request)
#         return f(*args, **kwargs)
#     return decorated_function
#
#
# @application.before_request
# def before_decorator():
#     print(".... In before decorator ...")
#
#
# @application.after_request
# def after_decorator(rsp):
#     print("... In after decorator ...")
#     return rsp
#
#
# class SimpleMiddleWare(object):
#
#     def __init__(self, app):
#         self.app = app
#
#     def __call__(self, environ, start_response):
#         print ("\n\nSimpleMiddlewareObject: something you want done in every http request")
#         return self.app(environ, start_response)
#
#
# class MWResponse(wResponse):
#
#     def __init__(self, response=None, status=None, headers=None,
#                  mimetype=None, content_type=None, direct_passthrough=None):
#         super().__init__(response, status, headers, mimetype, content_type, direct_passthrough)
#         print("\nMWResponse was used in place of just response!")
#
#
# # Middleware
# application.wsgi_app = SimpleMiddleWare(application.wsgi_app)
#
#
#
# # This function performs a basic health check. We will flesh this out.
# @application.route("/health", methods=["GET"])
# @login_required
# def health_check():
#
#     rsp_data = { "status": "healthy", "time": str(datetime.now()) }
#     rsp_str = json.dumps(rsp_data)
#     print("\nHealth is returning ...", rsp_str, "\n")
#     rsp = MWResponse(rsp_str, status=200, content_type="application/json")
#     return rsp
#
#
# def do_something_before():
#     print("\n")
#     print("***************** Do something before got ... **************", request)
#     print("\n")
#
#
# def do_something_after(rsp):
#     print("\n")
#     print("***************** Do something AFTER got ... **************", request)
#     print("\n")
#     return rsp
#
#
# # run the app.
# if __name__ == "__main__":
#     # Setting debug to True enables debug output. This line should be
#     # removed before deploying a production app.
#
#     application.debug = False
#     application.before_request(do_something_before)
#     application.after_request(do_something_after)
#     application.run(port=5034)
#
# ```

# %% [markdown]
# <br>
#
# # Putting Together Middleware and Security
#
# <br>
#
# - We will use middleware in your ```application.py``` or equivalent microservice route handles to implement:
#     - Requiring an ```Authorization``` header for some routes. Not, this implements/enforces __authentication.__
#     - Perform authorization for operations.<br><br>
#
# <br>
#
# <hr>
#
# | <img src="../../images/http_errors.png"> |
# | :---: |
# | [Some HTTP Errors](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status) |
#
# <hr>
#
# <br>

# %% [markdown]
# <br>
#
# __Tasks/Steps:__<br><br>
#
# 1. Implement a relation database behind the ```User Microservice.```
#     - ```Users(id, last_name, first_name, email, ... ..., hashed_password)```
#     - ```AllowedRoles(user_id, role_name)```<br><br>
#
# 2. Implement two routes/paths:
#     - POST ```/users/register```
#         - Creates an entry in the ```Users``` table.
#         - Stores hashed password.
#     - POST ```/users/login```
#         - Body is ```email``` and ```password.```
#         - Validates password.
#         - Returns a signed JWT Token header that contains:
#             - User identity.
#             - Roles the user can assume.
#     - Subsequent requests contain the Authorization header.<br><br>
#
# 3. Implement simple _before_ and _after_ middleware to require login for some paths and check authorization for some paths.

# %% [markdown]
# <br>
#
# # Database-as-a-Service
#
# <br>
#
# ## Concepts
#
# <hr>
#
#
# | <img src="../../images/dbaas_1.jpg"> |
# | :---: |
# | [Database-as-a-Service](https://labs.sogeti.com/cloud-database-dbaas-database-as-a-service/) |
#
# <hr>
#
# <br>
#
# - From [Wikipedia:](https://en.wikipedia.org/wiki/Cloud_database)<br><br>
#
# "A cloud database is a database that typically runs on a cloud computing platform, and access to the database is provided as-a-service.
#
# Database services take care of scalability and high availability of the database. Database services make the underlying software-stack transparent to the user."
#
# <br><br>
#
# - There are several approaches to DBaaS and several implementation models.<br><br>
#
# <br>
#
# <hr>
#
#
# | <img src="../../images/dbaas_2.png"> |
# | :---: |
# | [Database-as-a-Service]() |
#
# <hr>
#
# <br>

# %% [markdown]
# <br>
#
# ## Some Databases
#
# <br>
#
# <hr>
#
# | <img src="../../images/dbaas_3.png"> |
# | :---: |
# | __AWS Database-as-a-Service__ |
#
# <hr>
#
# <br>
#
# __Note:__
# 1. Why are we so AWS centric? Aren't there other clouds?
# 2. Yes, and they have impressive functions, but ... ...
# 3. I am having about as much fun as I can managing cloud accounts, credits, security on one cloud, and would really not want to support you on multiple clouds.
#
# <br>
#
# - We will start with AWS RDS and/or Aurora and DynamoDB.

# %% [markdown]
# <br>
#
# # AWS RDS and Aurora
#
# <br>
#
# ## Concept
#
# <br>
#
# - With RDS, e.g. MySQL, you are more aware of the "virtual machine."<br><br>
#
# - Aurora (serverless option) is more of DB via a PaaS model.<br><br>
#
# - You have a "database API endpoint."
#
# <br>
#
# <hr>
#
# | <img src="../../images/aws_aurora.png"> |
# | :---: |
# | __AWS Database-as-a-Service__ |
#
# <hr>
#
# <br>
#
# - For now, we will use RDS MySQL because I am still trying to figure out remote access to Aurora.<br><br>

# %% [markdown]
# ## Create and Use RDS Database
#
# <br>
#
# - Walk through create steps, __and explain remote access and inbound rules.__<br><br>

# %%
#
#
user = "dff"
password =

# %%
import pymysql

conn = pymysql.connect(
    host="w4111f20.ckkqqktwkcji.us-east-1.rds.amazonaws.com",
    user=user,
    password=password,
    cursorclass=pymysql.cursors.DictCursor)

conn

# %%
cur = conn.cursor()

res = cur.execute("select * from classicmodels.customers limit 5")
res = cur.fetchall()

import json

print("Result = \n", json.dumps(res, indent=4, default=str))
# Out:
# Result =
#  [
#     {
#         "customerNumber": 103,
#         "customerName": "Atelier graphique",
#         "contactLastName": "Schmitt",
#         "contactFirstName": "Carine ",
#         "phone": "40.32.2555",
#         "addressLine1": "54, rue Royale",
#         "addressLine2": null,
#         "city": "Nantes",
#         "state": null,
#         "postalCode": "44000",
#         "country": "France",
#         "salesRepEmployeeNumber": 1370,
#         "creditLimit": "21000.00"
#     },
#     {
#         "customerNumber": 112,
#         "customerName": "Signal Gift Stores",
#         "contactLastName": "King",
#         "contactFirstName": "Jean",
#         "phone": "7025551838",
#         "addressLine1": "8489 Strong St.",
#         "addressLine2": null,
#         "city": "Las Vegas",
#         "state": "NV",
#         "postalCode": "83030",
#         "country": "USA",
#         "salesRepEmployeeNumber": 1166,
#         "creditLimit": "71800.00"
#     },
#     {
# ...

# %% [markdown]
# ## DynamoDB Introduction/Concepts
#
# <br>
#
# ### Data Model
#
# <br>
#
# <hr>
#
# | <img src="../../images/dynamo1.jpg"> |
# | :---: |
# | __Relational Model versus DynamoDB |
#
# <hr>
#
# <br>
#
# <br>
#
# <hr>
#
# | <img src="../../images/dynamo_2.jpg"> |
# | :---: |
# | __Relational Model versus DynamoDB |
#
# <hr>
#
# <br>

# %% [markdown]
# <br>
#
# - The relational model is, well, "relational."
#     - Tables
#     - Very spreadsheet like.
#     - Each (row, column) value is some atomic type, e.g. int, string, ... ...<br><br>
#
# - DynamoDB is a _Key Value_ database.<br><br>
#
# - From AWS:<br><br>
#
# "A key-value database is a type of nonrelational database that uses a simple key-value method to store data. A key-value database stores data as a collection of key-value pairs in which a key serves as a unique identifier. Both keys and values can be anything, ranging from simple objects to __complex compound objects.__ Key-value databases are highly partitionable and allow horizontal scaling at scales that other types of databases cannot achieve." (Emphasis added)<br><br>
#
# <br>
#
# <hr>
#
# | <img src="../../images/dynamo_3.png"> |
# | :---: |
# | __Relational Model versus DynamoDB |
#
# <hr>
#
# <br>
#
# <br>
#
# <hr>
#
# | <img src="../../images/dynamo_4.png"> |
# | :---: |
# | __Relational Model versus DynamoDB |
#
# <hr>
#
# <br>

# %% [markdown]
# <br>
#
# - The _List_ and _Map_ types are the critical differences. They allow for nested, complex attributes.<br><br>
#     - This is more "document" like.
#     - The schema is not fixes.
#     - This is very hard to do in relational.<br><br>
#
# - Threaded, nested discussions are a good example.<br><br>
#
# ```
# {
#   "comment": "This guy is the nutties professor I have ever seen.",
#   "comment_id": "1234",
#   "datetime": "2020-10-09 12:01",
#   "responses": [
#     {
#       "comment": "Seriously. Nutty does not even begin to capture it.",
#       "datetime": "2020-10-09 12:01",
#       "user_id": "bbb@xxx,com"
#     },
#     {
#       "comment": "Lunatic.",
#       "datetime": "2020-10-09 12:01",
#       "responses": [
#         {
#           "comment": "That is a bit harsh!",
#           "datetime": "2020-10-09 12:01",
#           "user_id": "eee@xxx,com"
#         }
#       ],
#       "user_id": "ccc@xxx,com"
#     }
#   ],
#   "tags": [
#     "Cloud",
#     "BaaS",
#     "Nutty Professor"
#   ],
#   "user_id": "dff@cs.columbia.edu"
# }
#
# ```

# %% [markdown]
# <br>
#
# ### Partitioning and Scale-Out
#
# <br>
#
# <hr>
#
#
# | <img src="../../images/dynamodb_partitions.png" width="900px"> |
# | :---: |
# | [DynamoDB Concept](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/HowItWorks.Partitions.html)
#
# <hr>
#
# <br>

# %% [markdown]
# <br>
#
# - A DynamoDB "table" has one or more _partitions._ and must define a _partition key_ that is a data field on ALL entries in the table.<br><br>
#
#
# - DynamoDB processes operations by:
#     - Getting the partition key value from the request data.
#     - Hashing to determine the partition.
#     - Routing the request to the partition that contains (may contain) the data.
#
# <br><nr>
#
#
# __Some Database Server/Data Layer Design Patterns__<br><br>
#
# - There are two [basic approaches to scalability:](https://en.wikipedia.org/wiki/Scalability#Horizontal_and_vertical_scaling)
#     - Horizontal aka scale-out: add more (or less) systems.
#     - Vertical aka scale-up: Use a bigger system (more CPUs, memory, disk, ...)<br>
#
# <br>
#
# <hr>
#
# | <img src="../../images/scale_up_out.jpeg"> |
# | :---: |
# | __Scale-Up and Scale-Out__ |
#
# <hr>
# <br>
#
#  - There are pros and cons to each approach.<br><br>
#
#
#  - RDB's basic pattern is scale-up. DynamoDB's pattern is scale-out.<br><br>
#
#
#  - You can also think in terms of _shared everything_ versus _shared nothing._<br><br>
#
#  <br>
#
# <hr>
#
# | <img src="../../images/shared-nothing-comparison.jpg" width="900px"> |
# | :---: |
# | [Shared Everything vs. Shared Nothing](https://www.morpheusdata.com/blog/shared-nothing-architecture) |
#
# <hr>
#
# <br>

# %% [markdown]
# <br>
#
# - RDBs tend to favor _shared everything._ DynamoDB is _shared nothing._<br><br>
#
#
# - Shared nothing/scale out works
#     - Extremely well for:
#         - Scans
#         - Individual item read/write/update.
#     - Poorly for:
#         - Referential integrity.
#         - Multi-table/type operations, e.g. JOIN.<br><br>
#
# - Shared everything/scale up works
#     - Extremely well for:
#         - Complex, multi-table/type queries.
#         - Referential integrity.
#     - Poorly for:
#         - Massive scalability.
#         - Availability.<br><br>
#
#
# - I conflated scale up/versus scale out with shared everything/shared nothing. There is some ability to mix and match, but in general the two patterns are scale out/shared nothing and scale up/share everything.
